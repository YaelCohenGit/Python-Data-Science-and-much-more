# %%
import matplotlib.pyplot as plt

# %%
# 1
x = [1, 2, 3, 4, 5]
y = [25,30,35,69,70]
plt.plot(x,y)
plt.show()

# %%
# 2
time = [0, 1, 2, 3, 4, 5, 6]
co2_concentration = [250, 265, 272, 260, 300, 320, 389]
plt.plot(time, co2_concentration)

# %%
time = [0, 1, 2, 3, 4, 5, 6]
co2_concentration = [250, 265, 272, 260, 300, 320, 389]
plt.plot(time, co2_concentration, linewidth=5, ls="--", color="c")
plt.title("Chemistry Data")
plt.xlabel("Time")
plt.ylabel("Co2_Concentration")
# Out:
# Text(0, 0.5, 'Co2_Concentration')

# %%
time = [0, 1, 2, 3, 4, 5, 6]
co2 = [250, 265, 272, 260, 300, 320, 389]
Temp = [14.1,15.5,16.3,18.1,17.3,19.1,20.2]
plt.plot(time, co2, Temp)
